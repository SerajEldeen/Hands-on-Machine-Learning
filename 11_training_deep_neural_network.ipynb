# %% [markdown]
# ## Vanishing/Exploding Gradients Problems

# %%
import tensorflow as tf
from tensorflow import keras
# Out:
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %% [markdown]
# ### Xavier and He Initialization

# %%
[name for name in dir(keras.initializers) if not name.startswith("_")]
# Out:
# ['Constant',
#  'GlorotNormal',
#  'GlorotUniform',
#  'HeNormal',
#  'HeUniform',
#  'Identity',
#  'IdentityInitializer',
#  'Initializer',
#  'LecunNormal',
#  'LecunUniform',
#  'Ones',
#  'Orthogonal',
#  'OrthogonalInitializer',
#  'RandomNormal',
#  'RandomUniform',
#  'STFT',
#  'STFTInitializer',
#  'TruncatedNormal',
#  'VarianceScaling',
#  'Zeros',
#  'constant',
#  'deserialize',
#  'get',
#  'glorot_normal',
#  'glorot_uniform',
#  'he_normal',
#  'he_uniform',
#  'identity',
#  'lecun_normal',
#  'lecun_uniform',
#  'ones',
#  'orthogonal',
#  'random_normal',
#  'random_uniform',
#  'serialize',
#  'stft',
#  'truncated_normal',
#  'variance_scaling',
#  'zeros']

# %%
keras.layers.Dense(10,activation="relu",kernel_initializer="he_normal")
# Out:
# <Dense name=dense, built=False>

# %% [markdown]
# ### Lecun Initialization

# %%
init=keras.initializers.VarianceScaling(scale=2.,mode='fan_avg',
                                        distribution='uniform')
keras.layers.Dense(10,activation="relu",kernel_initializer=init)
# Out:
# <Dense name=dense_1, built=False>

# %% [markdown]
# ## Activation Functions

# %%
[m for m in dir(keras.activations) if not m.startswith("_")]
# Out:
# ['celu',
#  'deserialize',
#  'elu',
#  'exponential',
#  'gelu',
#  'get',
#  'glu',
#  'hard_shrink',
#  'hard_sigmoid',
#  'hard_silu',
#  'hard_swish',
#  'hard_tanh',
#  'leaky_relu',
#  'linear',
#  'log_sigmoid',
#  'log_softmax',
#  'mish',
#  'relu',
#  'relu6',
#  'selu',
#  'serialize',
#  'sigmoid',
#  'silu',
#  'soft_shrink',
#  'softmax',
#  'softplus',
#  'softsign',
#  'sparse_plus',
#  'sparse_sigmoid',
#  'sparsemax',
#  'squareplus',
#  'swish',
#  'tanh',
#  'tanh_shrink',
#  'threshold']

# %% [markdown]
# ### Relu Activation Functions

# %%
[m for m in dir(keras.layers) if "relu" in m.lower()]
# Out:
# ['LeakyReLU', 'PReLU', 'ReLU', 'ThresholdedReLU']

# %%
import numpy as np

# %%
(X_train_full, y_train_full), (X_test, y_test) = keras.datasets.fashion_mnist.load_data()
X_train_full = X_train_full / 255.0
X_test = X_test / 255.0
X_valid, X_train = X_train_full[:5000], X_train_full[5000:]
y_valid, y_train = y_train_full[:5000], y_train_full[5000:]

# %%
tf.random.set_seed(42)
np.random.seed(42)

model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[28, 28]),
    keras.layers.Dense(300, kernel_initializer="he_normal"),
    keras.layers.LeakyReLU(),
    keras.layers.Dense(100, kernel_initializer="he_normal"),
    keras.layers.LeakyReLU(),
    keras.layers.Dense(10, activation="softmax")
])
# Out:
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.SGD(learning_rate=1e-3),
              metrics=["accuracy"])

# %%
history = model.fit(X_train, y_train, epochs=10,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5974 - loss: 1.3310 - val_accuracy: 0.7074 - val_loss: 0.8979
# Epoch 2/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.7341 - loss: 0.8088 - val_accuracy: 0.7628 - val_loss: 0.7256
# Epoch 3/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.7714 - loss: 0.6946 - val_accuracy: 0.7890 - val_loss: 0.6483
# Epoch 4/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.7903 - loss: 0.6328 - val_accuracy: 0.8010 - val_loss: 0.6001
# Epoch 5/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8027 - loss: 0.5921 - val_accuracy: 0.8110 - val_loss: 0.5667
# Epoch 6/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8110 - loss: 0.5630 - val_accuracy: 0.8164 - val_loss: 0.5421
# Epoch 7/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8169 - loss: 0.5410 - val_accuracy: 0.8222 - val_loss: 0.5232
# Epoch 8/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8219 - loss: 0.5238 - val_accuracy: 0.8294 - val_loss: 0.5082
# Epoch 9/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8261 - loss: 0.5098 - val_accuracy: 0.8340 - val_loss: 0.4959
# Epoch 10/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8293 - loss: 0.4980 - val_accuracy: 0.8364 - val_loss: 0.4854

# %% [markdown]
# ### Batch Normalization

# %%
model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[28, 28]),
    keras.layers.BatchNormalization(),
    keras.layers.Dense(300, activation="relu"),
    keras.layers.BatchNormalization(),
    keras.layers.Dense(100, activation="relu"),
    keras.layers.BatchNormalization(),
    keras.layers.Dense(10, activation="softmax")
])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_1 (Flatten)             │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 784)            │         3,136 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 300)            │       235,500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 300)            │         1,200 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 100)            │        30,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 100)            │           400 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 10)             │         1,010 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 271,346 (1.04 MB)
#  Trainable params: 268,978 (1.03 MB)
#  Non-trainable params: 2,368 (9.25 KB)

# %%
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.SGD(learning_rate=1e-3),
              metrics=["accuracy"])

# %%
history = model.fit(X_train, y_train, epochs=10,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.7087 - loss: 0.8736 - val_accuracy: 0.8182 - val_loss: 0.5520
# Epoch 2/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8039 - loss: 0.5722 - val_accuracy: 0.8382 - val_loss: 0.4798
# Epoch 3/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8236 - loss: 0.5098 - val_accuracy: 0.8508 - val_loss: 0.4457
# Epoch 4/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8351 - loss: 0.4732 - val_accuracy: 0.8564 - val_loss: 0.4242
# Epoch 5/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8445 - loss: 0.4473 - val_accuracy: 0.8594 - val_loss: 0.4087
# Epoch 6/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8512 - loss: 0.4271 - val_accuracy: 0.8634 - val_loss: 0.3973
# Epoch 7/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8570 - loss: 0.4104 - val_accuracy: 0.8650 - val_loss: 0.3883
# Epoch 8/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8619 - loss: 0.3962 - val_accuracy: 0.8680 - val_loss: 0.3811
# Epoch 9/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8657 - loss: 0.3837 - val_accuracy: 0.8690 - val_loss: 0.3750
# Epoch 10/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8697 - loss: 0.3726 - val_accuracy: 0.8710 - val_loss: 0.3699

# %% [markdown]
# ## Transfer Learning and Unsupervised PreTrained

# %%
def split_dataset(X, y):
    y_5_or_6 = (y == 5) | (y == 6) # sandals or shirts
    y_A = y[~y_5_or_6]
    y_A[y_A > 6] -= 2 # class indices 7, 8, 9 should be moved to 5, 6, 7
    y_B = (y[y_5_or_6] == 6).astype(np.float32) # binary classification task: is it a shirt (class 6)?
    return ((X[~y_5_or_6], y_A),
            (X[y_5_or_6], y_B))

(X_train_A, y_train_A), (X_train_B, y_train_B) = split_dataset(X_train, y_train)
(X_valid_A, y_valid_A), (X_valid_B, y_valid_B) = split_dataset(X_valid, y_valid)
(X_test_A, y_test_A), (X_test_B, y_test_B) = split_dataset(X_test, y_test)
X_train_B = X_train_B[:200]
y_train_B = y_train_B[:200]

# %%
model_A = keras.models.Sequential()
model_A.add(keras.layers.Flatten(input_shape=[28, 28]))
for n_hidden in (300, 100, 50, 50, 50):
    model_A.add(keras.layers.Dense(n_hidden, activation="selu"))
model_A.add(keras.layers.Dense(8, activation="softmax"))

# %%
model_A.compile(loss="sparse_categorical_crossentropy",
                optimizer=keras.optimizers.SGD(learning_rate=1e-3),
                metrics=["accuracy"])

# %%
history = model_A.fit(X_train_A, y_train_A, epochs=20,
                    validation_data=(X_valid_A, y_valid_A))
# Out:
# Epoch 1/20
# 1375/1375 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.8115 - loss: 0.6037 - val_accuracy: 0.8672 - val_loss: 0.3891
# Epoch 2/20
# 1375/1375 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.8799 - loss: 0.3545 - val_accuracy: 0.8787 - val_loss: 0.3341
# Epoch 3/20
# 1375/1375 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.8915 - loss: 0.3168 - val_accuracy: 0.8874 - val_loss: 0.3105
# Epoch 4/20
# 1375/1375 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8977 - loss: 0.2968 - val_accuracy: 0.8959 - val_loss: 0.2957
# Epoch 5/20
# 1375/1375 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9025 - loss: 0.2834 - val_accuracy: 0.9011 - val_loss: 0.2856
# Epoch 6/20
# 1375/1375 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9061 - loss: 0.2736 - val_accuracy: 0.9048 - val_loss: 0.2774
# Epoch 7/20
# 1375/1375 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9089 - loss: 0.2658 - val_accuracy: 0.9081 - val_loss: 0.2711
# Epoch 8/20
# 1375/1375 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9109 - loss: 0.2594 - val_accuracy: 0.9103 - val_loss: 0.2661
# Epoch 9/20
# 1375/1375 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9128 - loss: 0.2540 - val_accuracy: 0.9113 - val_loss: 0.2621
# Epoch 10/20
# 1375/1375 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9145 - loss: 0.2493 - val_accuracy: 0.9118 - val_loss: 0.2591
# Epoch 11/20
# 1375/1375 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9159 - loss: 0.2452 - val_accuracy: 0.9121 - val_loss: 0.2564
# Epoch 12/20
# 1375/1375 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9169 - loss: 0.2415 - val_accuracy: 0.9128 - val_loss: 0.2538
# Epoch 13/20
# 1375/1375 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.9183 - loss: 0.2381 - val_accuracy: 0.9141 - val_loss: 0.2519
# Epoch 14/20
# 1375/1375 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - accuracy: 0.9196 - loss: 0.2349 - val_accuracy: 0.9148 - val_loss: 0.2498
# Epoch 15/20
# 1375/1375 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9204 - loss: 0.2321 - val_accuracy: 0.9153 - val_loss: 0.2482
# Epoch 16/20
# 1375/1375 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9214 - loss: 0.2293 - val_accuracy: 0.9155 - val_loss: 0.2466
# Epoch 17/20
# 1375/1375 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9225 - loss: 0.2268 - val_accuracy: 0.9160 - val_loss: 0.2456
# Epoch 18/20
# 1375/1375 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9234 - loss: 0.2244 - val_accuracy: 0.9155 - val_loss: 0.2445
# Epoch 19/20
# 1375/1375 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9242 - loss: 0.2220 - val_accuracy: 0.9165 - val_loss: 0.2431
# Epoch 20/20
# 1375/1375 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9251 - loss: 0.2198 - val_accuracy: 0.9170 - val_loss: 0.2423

# %%
model_A.save("my_model_A.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
model_B = keras.models.Sequential()
model_B.add(keras.layers.Flatten(input_shape=[28, 28]))
for n_hidden in (300, 100, 50, 50, 50):
    model_B.add(keras.layers.Dense(n_hidden, activation="selu"))
model_B.add(keras.layers.Dense(1, activation="sigmoid"))
# Out:
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model_B.compile(loss="binary_crossentropy",
                optimizer=keras.optimizers.SGD(learning_rate=1e-3),
                metrics=["accuracy"])

# %%
history = model_B.fit(X_train_B, y_train_B, epochs=20,
                      validation_data=(X_valid_B, y_valid_B))
# Out:
# Epoch 1/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - accuracy: 0.6650 - loss: 0.6919 - val_accuracy: 0.7444 - val_loss: 0.5498
# Epoch 2/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8050 - loss: 0.4697 - val_accuracy: 0.8245 - val_loss: 0.4090
# Epoch 3/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9050 - loss: 0.3449 - val_accuracy: 0.8803 - val_loss: 0.3239
# Epoch 4/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9300 - loss: 0.2701 - val_accuracy: 0.9158 - val_loss: 0.2685
# Epoch 5/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9400 - loss: 0.2215 - val_accuracy: 0.9351 - val_loss: 0.2306
# Epoch 6/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9500 - loss: 0.1883 - val_accuracy: 0.9473 - val_loss: 0.2028
# Epoch 7/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9650 - loss: 0.1639 - val_accuracy: 0.9584 - val_loss: 0.1815
# Epoch 8/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9800 - loss: 0.1451 - val_accuracy: 0.9655 - val_loss: 0.1648
# Epoch 9/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9800 - loss: 0.1303 - val_accuracy: 0.9696 - val_loss: 0.1514
# Epoch 10/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9800 - loss: 0.1183 - val_accuracy: 0.9706 - val_loss: 0.1403
# Epoch 11/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9850 - loss: 0.1084 - val_accuracy: 0.9716 - val_loss: 0.1310
# Epoch 12/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9850 - loss: 0.1000 - val_accuracy: 0.9777 - val_loss: 0.1230
# Epoch 13/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9900 - loss: 0.0928 - val_accuracy: 0.9787 - val_loss: 0.1161
# Epoch 14/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9900 - loss: 0.0866 - val_accuracy: 0.9797 - val_loss: 0.1101
# Epoch 15/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9900 - loss: 0.0811 - val_accuracy: 0.9828 - val_loss: 0.1048
# Epoch 16/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9900 - loss: 0.0764 - val_accuracy: 0.9828 - val_loss: 0.1001
# Epoch 17/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9900 - loss: 0.0722 - val_accuracy: 0.9838 - val_loss: 0.0960
# Epoch 18/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9900 - loss: 0.0685 - val_accuracy: 0.9838 - val_loss: 0.0923
# Epoch 19/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9900 - loss: 0.0652 - val_accuracy: 0.9848 - val_loss: 0.0890
# Epoch 20/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9900 - loss: 0.0622 - val_accuracy: 0.9858 - val_loss: 0.0859

# %%
model_B.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_3 (Flatten)             │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 300)            │       235,500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 100)            │        30,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 50)             │         5,050 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 50)             │         2,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_18 (Dense)                │ (None, 50)             │         2,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_19 (Dense)                │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 275,803 (1.05 MB)
#  Trainable params: 275,801 (1.05 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2 (12.00 B)

# %%
model_A_clone = keras.models.clone_model(model_A)
model_A_clone.set_weights(model_A.get_weights())
model_B_on_A = keras.models.Sequential(model_A_clone.layers[:-1])
model_B_on_A.add(keras.layers.Dense(1, activation="sigmoid"))

# %%
for layer in model_B_on_A.layers[:-1]:
    layer.trainable = False

model_B_on_A.compile(loss="binary_crossentropy",
                     optimizer=keras.optimizers.SGD(learning_rate=1e-3),
                     metrics=["accuracy"])

# %%
history = model_B_on_A.fit(X_train_B, y_train_B, epochs=4,
                           validation_data=(X_valid_B, y_valid_B))

for layer in model_B_on_A.layers[:-1]:
    layer.trainable = True

model_B_on_A.compile(loss="binary_crossentropy",
                     optimizer=keras.optimizers.SGD(learning_rate=1e-3),
                     metrics=["accuracy"])
history = model_B_on_A.fit(X_train_B, y_train_B, epochs=16,
                           validation_data=(X_valid_B, y_valid_B))
# Out:
# Epoch 1/4
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - accuracy: 0.4850 - loss: 0.8443 - val_accuracy: 0.5781 - val_loss: 0.7878
# Epoch 2/4
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5700 - loss: 0.7654 - val_accuracy: 0.6369 - val_loss: 0.7199
# Epoch 3/4
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.6250 - loss: 0.6964 - val_accuracy: 0.6856 - val_loss: 0.6605
# Epoch 4/4
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.7050 - loss: 0.6362 - val_accuracy: 0.7252 - val_loss: 0.6084
# Epoch 1/16
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - accuracy: 0.8100 - loss: 0.4911 - val_accuracy: 0.8590 - val_loss: 0.3778
# Epoch 2/16
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9200 - loss: 0.3190 - val_accuracy: 0.9219 - val_loss: 0.2814
# Epoch 3/16
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9600 - loss: 0.2391 - val_accuracy: 0.9523 - val_loss: 0.2246
# Epoch 4/16
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9850 - loss: 0.1905 - val_accuracy: 0.9746 - val_loss: 0.1872
# Epoch 5/16
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9900 - loss: 0.1578 - val_accuracy: 0.9858 - val_loss: 0.1607
# Epoch 6/16
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9950 - loss: 0.1344 - val_accuracy: 0.9888 - val_loss: 0.1410
# Epoch 7/16
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9950 - loss: 0.1169 - val_accuracy: 0.9909 - val_loss: 0.1258
# Epoch 8/16
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9950 - loss: 0.1034 - val_accuracy: 0.9929 - val_loss: 0.1138
# Epoch 9/16
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9950 - loss: 0.0927 - val_accuracy: 0.9929 - val_loss: 0.1042
# Epoch 10/16
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9950 - loss: 0.0840 - val_accuracy: 0.9939 - val_loss: 0.0962
# Epoch 11/16
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 0.0769 - val_accuracy: 0.9939 - val_loss: 0.0895
# Epoch 12/16
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0708 - val_accuracy: 0.9939 - val_loss: 0.0837
# Epoch 13/16
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0657 - val_accuracy: 0.9949 - val_loss: 0.0788
# Epoch 14/16
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0613 - val_accuracy: 0.9949 - val_loss: 0.0745
# Epoch 15/16
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.0574 - val_accuracy: 0.9949 - val_loss: 0.0708
# Epoch 16/16
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.0540 - val_accuracy: 0.9949 - val_loss: 0.0675

# %%
model_B.evaluate(X_test_B, y_test_B)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9860 - loss: 0.0870
# [0.08704958856105804, 0.9860000014305115]

# %%
model_B_on_A.evaluate(X_test_B, y_test_B)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9925 - loss: 0.0683
# [0.0682678297162056, 0.9925000071525574]

# %% [markdown]
# ## Faster Optimizers

# %% [markdown]
# ### Momentum optimization

# %%
optimizer=keras.optimizers.SGD(learning_rate=0.001,momentum=0.9)

# %% [markdown]
# ### Nesterov Accelerated Gradient

# %%
optimizer=keras.optimizers.SGD(learning_rate=0.001,momentum=0.9,nesterov=True)

# %% [markdown]
# ### AdaGrad

# %%
optimizer=keras.optimizers.Adagrad(learning_rate=0.001)

# %% [markdown]
# ### RMSProp

# %%
optimizer=keras.optimizers.RMSprop(learning_rate=0.001,rho=0.9)

# %% [markdown]
# ### Adam Optimization

# %%
optimizer=keras.optimizers.Adam(learning_rate=0.001,beta_1=0.9,beta_2=0.999)

# %% [markdown]
# ### Adamax Optimization

# %%
optimizer=keras.optimizers.Adamax(learning_rate=0.001,beta_1=0.9,beta_2=0.999)

# %% [markdown]
# ### Nadam Optimization

# %%
optimizer=keras.optimizers.Nadam(learning_rate=0.001,beta_1=0.9,beta_2=0.999)

# %% [markdown]
# ## Book summary
#  (* is bad, ** is average,
# and *** is good).
# | Optimizer      | Speed | Quality  |
# | -------------- | ----- | -------- |
# | SGD            | *     | ***      |
# | SGD + Momentum | **    | ***      |
# | Nesterov       | **    | ***      |
# | AdaGrad        | ***   | *        |
# | RMSProp        | ***   | ** / *** |
# | Adam           | ***   | ** / *** |
# | Nadam          | ***   | ** / *** |
# | AdaMax         | ***   | ** / *** |

# %% [markdown]
# ## Learning Rate Scheduling

# %% [markdown]
# ### Power Scheduling

# %%
optimizer = keras.optimizers.SGD(learning_rate=0.01, decay=1e-4)
# Out:
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\optimizers\base_optimizer.py:86: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(

# %% [markdown]
# ### Exponential Scheduling

# %%
def exponential_decay_fn(epoch):
    return 0.01 * 0.1**(epoch / 20)



lr_scheduler = keras.callbacks.LearningRateScheduler(exponential_decay_fn)

# %% [markdown]
# ### Piecewise Constant Scheduling

# %%
def piecewise_constant_fn(epoch):
    if epoch < 5:
        return 0.01
    elif epoch < 15:
        return 0.005
    else:
        return 0.001

# %% [markdown]
# ### Performance Scheduling

# %%
lr_scheduler = keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=5)

# %% [markdown]
# ### Which schedule to use
#
# | Method                | Speed | Control | When to Use                     |
# | --------------------- | ----- | ------- | ------------------------------- |
# | Power Decay           | ★★★   | ★★      | General work                    |
# | Exponential Decay     | ★★★★  | ★★      | Fast, stable decay              |
# | Piecewise Constant    | ★★★   | ★★★★★   | Large datasets, planning phases |
# | Performance (Plateau) | ★★★★  | ★★★     | Very reliable general purpose   |
# | ⭐ 1Cycle              | ⭐⭐⭐⭐⭐ | ⭐⭐⭐     | Best results, fastest training  |

# %% [markdown]
# ## Regularization Technique

# %% [markdown]
# ### L1 and L2 regularization

# %%
layer=keras.layers.Dense(100,activation="elu",
                         kernel_initializer="he_normal",
                         kernel_regularizer=keras.regularizers.l2(0.01))

# %%
model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[28, 28]),
    keras.layers.Dense(300, activation="elu",
                       kernel_initializer="he_normal",
                       kernel_regularizer=keras.regularizers.l2(0.01)),
    keras.layers.Dense(100, activation="elu",
                       kernel_initializer="he_normal",
                       kernel_regularizer=keras.regularizers.l2(0.01)),
    keras.layers.Dense(10, activation="softmax",
                       kernel_regularizer=keras.regularizers.l2(0.01))
])
model.compile(loss="sparse_categorical_crossentropy",optimizer="adam",metrics=["accuracy"])
# Out:
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
from functools import partial

RegularizedDense = partial(keras.layers.Dense,
                           activation="elu",
                           kernel_initializer="he_normal",
                           kernel_regularizer=keras.regularizers.l2(0.01))

model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[28, 28]),
    RegularizedDense(300),
    RegularizedDense(100),
    RegularizedDense(10, activation="softmax")
])
model.compile(loss="sparse_categorical_crossentropy", optimizer="nadam", metrics=["accuracy"])

# %% [markdown]
# ### Dropout

# %%
model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[28, 28]),
    keras.layers.Dropout(rate=0.2),
    keras.layers.Dense(300, activation="elu", kernel_initializer="he_normal"),
    keras.layers.Dropout(rate=0.2),
    keras.layers.Dense(100, activation="elu", kernel_initializer="he_normal"),
    keras.layers.Dropout(rate=0.2),
    keras.layers.Dense(10, activation="softmax")
])
model.compile(loss="sparse_categorical_crossentropy", optimizer="nadam", metrics=["accuracy"])

# %% [markdown]
# ### Alpha Dropout

# %%
model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[28, 28]),
    keras.layers.AlphaDropout(rate=0.2),
    keras.layers.Dense(300, activation="selu", kernel_initializer="lecun_normal"),
    keras.layers.AlphaDropout(rate=0.2),
    keras.layers.Dense(100, activation="selu", kernel_initializer="lecun_normal"),
    keras.layers.AlphaDropout(rate=0.2),
    keras.layers.Dense(10, activation="softmax")
])
optimizer = keras.optimizers.SGD(learning_rate=0.01, momentum=0.9, nesterov=True)
model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer, metrics=["accuracy"])

# %% [markdown]
# ### MC Dropout

# %%
import numpy as np
y_probas = np.stack([model(X_test, training=True)
                     for sample in range(100)])
y_proba = y_probas.mean(axis=0)
y_std = y_probas.std(axis=0)

# %%
np.round(model.predict(X_test[:1]), 2)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step
# array([[0.06, 0.07, 0.06, 0.08, 0.17, 0.15, 0.07, 0.14, 0.09, 0.12]],
#       dtype=float32)

# %%
np.round(y_probas[:, :1], 2)
# Out:
# array([[[0.04, 0.01, 0.01, 0.05, 0.26, 0.16, 0.15, 0.02, 0.22, 0.07]],
#
#        [[0.07, 0.03, 0.02, 0.09, 0.2 , 0.08, 0.14, 0.23, 0.12, 0.03]],
#
#        [[0.03, 0.07, 0.13, 0.26, 0.11, 0.07, 0.02, 0.27, 0.01, 0.02]],
#
#        [[0.01, 0.  , 0.46, 0.13, 0.01, 0.03, 0.05, 0.01, 0.02, 0.29]],
#
#        [[0.01, 0.1 , 0.12, 0.03, 0.01, 0.21, 0.  , 0.22, 0.14, 0.16]],
#
#        [[0.09, 0.  , 0.01, 0.22, 0.03, 0.05, 0.05, 0.04, 0.44, 0.06]],
#
#        [[0.04, 0.06, 0.14, 0.22, 0.24, 0.16, 0.06, 0.01, 0.04, 0.04]],
#
#        [[0.11, 0.03, 0.04, 0.12, 0.01, 0.25, 0.1 , 0.28, 0.02, 0.04]],
#
#        [[0.06, 0.01, 0.05, 0.01, 0.56, 0.01, 0.1 , 0.01, 0.16, 0.04]],
#
#        [[0.17, 0.04, 0.07, 0.4 , 0.  , 0.01, 0.08, 0.19, 0.01, 0.02]],
#
#        [[0.06, 0.07, 0.17, 0.02, 0.45, 0.02, 0.01, 0.11, 0.01, 0.06]],
#
#        [[0.02, 0.02, 0.25, 0.26, 0.06, 0.05, 0.  , 0.02, 0.16, 0.16]],
#
#        [[0.05, 0.15, 0.19, 0.05, 0.01, 0.03, 0.12, 0.17, 0.17, 0.06]],
#
#        [[0.14, 0.01, 0.05, 0.06, 0.41, 0.1 , 0.15, 0.02, 0.03, 0.04]],
#
#        [[0.01, 0.12, 0.07, 0.1 , 0.08, 0.22, 0.02, 0.02, 0.04, 0.32]],
#
#        [[0.3 , 0.05, 0.01, 0.07, 0.26, 0.02, 0.12, 0.02, 0.02, 0.12]],
#
#        [[0.04, 0.64, 0.14, 0.02, 0.04, 0.01, 0.03, 0.01, 0.04, 0.03]],
#
#        [[0.05, 0.04, 0.02, 0.09, 0.02, 0.41, 0.02, 0.11, 0.02, 0.22]],
#
#        [[0.14, 0.1 , 0.07, 0.06, 0.02, 0.04, 0.08, 0.06, 0.05, 0.38]],
#
#        [[0.16, 0.01, 0.09, 0.01, 0.58, 0.08, 0.03, 0.01, 0.01, 0.03]],
#
#        [[0.04, 0.31, 0.2 , 0.02, 0.04, 0.04, 0.03, 0.3 , 0.  , 0.02]],
#
#        [[0.01, 0.04, 0.07, 0.02, 0.45, 0.03, 0.09, 0.15, 0.07, 0.08]],
#
#        [[0.  , 0.03, 0.12, 0.06, 0.03, 0.11, 0.03, 0.55, 0.  , 0.06]],
#
#        [[0.03, 0.01, 0.09, 0.01, 0.16, 0.  , 0.04, 0.  , 0.04, 0.63]],
#
#        [[0.  , 0.01, 0.02, 0.01, 0.92, 0.01, 0.01, 0.01, 0.01, 0.  ]],
#
#        [[0.2 , 0.03, 0.01, 0.04, 0.04, 0.2 , 0.13, 0.21, 0.01, 0.12]],
#
#        [[0.  , 0.02, 0.49, 0.02, 0.13, 0.21, 0.03, 0.05, 0.01, 0.03]],
#
#        [[0.  , 0.11, 0.03, 0.01, 0.49, 0.17, 0.06, 0.07, 0.03, 0.02]],
#
#        [[0.04, 0.08, 0.07, 0.02, 0.1 , 0.18, 0.05, 0.33, 0.04, 0.1 ]],
#
#        [[0.01, 0.1 , 0.12, 0.11, 0.35, 0.05, 0.07, 0.08, 0.1 , 0.01]],
#
#        [[0.01, 0.18, 0.03, 0.11, 0.1 , 0.2 , 0.17, 0.07, 0.03, 0.11]],
#
#        [[0.02, 0.22, 0.19, 0.02, 0.06, 0.1 , 0.08, 0.01, 0.21, 0.09]],
#
#        [[0.03, 0.11, 0.08, 0.04, 0.17, 0.05, 0.15, 0.13, 0.01, 0.23]],
#
#        [[0.11, 0.38, 0.08, 0.  , 0.14, 0.02, 0.02, 0.03, 0.02, 0.2 ]],
#
#        [[0.07, 0.03, 0.05, 0.03, 0.2 , 0.45, 0.02, 0.12, 0.  , 0.03]],
#
#        [[0.03, 0.22, 0.09, 0.01, 0.06, 0.1 , 0.  , 0.42, 0.03, 0.03]],
#
#        [[0.  , 0.04, 0.23, 0.01, 0.05, 0.24, 0.02, 0.19, 0.11, 0.1 ]],
#
#        [[0.15, 0.04, 0.  , 0.51, 0.07, 0.08, 0.1 , 0.02, 0.01, 0.02]],
#
#        [[0.04, 0.05, 0.01, 0.04, 0.04, 0.03, 0.05, 0.03, 0.44, 0.26]],
#
#        [[0.12, 0.16, 0.04, 0.1 , 0.01, 0.06, 0.15, 0.05, 0.07, 0.22]],
#
#        [[0.06, 0.02, 0.01, 0.16, 0.07, 0.2 , 0.27, 0.1 , 0.08, 0.02]],
#
#        [[0.15, 0.25, 0.01, 0.04, 0.1 , 0.1 , 0.01, 0.03, 0.24, 0.07]],
#
#        [[0.08, 0.03, 0.56, 0.11, 0.04, 0.03, 0.  , 0.11, 0.03, 0.01]],
#
#        [[0.34, 0.05, 0.11, 0.09, 0.15, 0.03, 0.13, 0.01, 0.01, 0.07]],
#
#        [[0.1 , 0.05, 0.  , 0.06, 0.27, 0.23, 0.04, 0.03, 0.14, 0.08]],
#
#        [[0.03, 0.06, 0.21, 0.12, 0.12, 0.01, 0.2 , 0.04, 0.12, 0.09]],
#
#        [[0.01, 0.01, 0.05, 0.01, 0.54, 0.04, 0.02, 0.02, 0.28, 0.01]],
#
#        [[0.23, 0.21, 0.13, 0.16, 0.02, 0.04, 0.04, 0.02, 0.11, 0.04]],
#
#        [[0.25, 0.02, 0.06, 0.1 , 0.11, 0.02, 0.04, 0.11, 0.22, 0.06]],
#
#        [[0.06, 0.04, 0.03, 0.03, 0.09, 0.04, 0.01, 0.01, 0.33, 0.34]],
#
#        [[0.17, 0.  , 0.05, 0.08, 0.06, 0.05, 0.03, 0.05, 0.43, 0.08]],
#
#        [[0.09, 0.1 , 0.1 , 0.  , 0.49, 0.12, 0.02, 0.01, 0.03, 0.04]],
#
#        [[0.09, 0.28, 0.14, 0.02, 0.01, 0.11, 0.05, 0.01, 0.1 , 0.17]],
#
#        [[0.06, 0.06, 0.03, 0.02, 0.08, 0.3 , 0.1 , 0.24, 0.03, 0.07]],
#
#        [[0.03, 0.09, 0.02, 0.04, 0.23, 0.01, 0.04, 0.22, 0.04, 0.29]],
#
#        [[0.05, 0.25, 0.2 , 0.06, 0.07, 0.03, 0.03, 0.17, 0.11, 0.02]],
#
#        [[0.02, 0.17, 0.02, 0.04, 0.2 , 0.06, 0.07, 0.03, 0.32, 0.08]],
#
#        [[0.16, 0.09, 0.14, 0.01, 0.29, 0.15, 0.07, 0.06, 0.02, 0.01]],
#
#        [[0.14, 0.1 , 0.02, 0.09, 0.02, 0.16, 0.23, 0.12, 0.04, 0.09]],
#
#        [[0.06, 0.03, 0.67, 0.03, 0.04, 0.  , 0.11, 0.03, 0.02, 0.01]],
#
#        [[0.01, 0.01, 0.03, 0.  , 0.02, 0.11, 0.02, 0.76, 0.04, 0.01]],
#
#        [[0.01, 0.01, 0.31, 0.05, 0.36, 0.1 , 0.08, 0.06, 0.01, 0.02]],
#
#        [[0.2 , 0.1 , 0.03, 0.01, 0.41, 0.09, 0.02, 0.02, 0.09, 0.04]],
#
#        [[0.02, 0.33, 0.05, 0.09, 0.07, 0.11, 0.03, 0.15, 0.02, 0.12]],
#
#        [[0.01, 0.05, 0.03, 0.01, 0.  , 0.56, 0.01, 0.29, 0.01, 0.02]],
#
#        [[0.01, 0.01, 0.02, 0.02, 0.13, 0.12, 0.02, 0.07, 0.57, 0.03]],
#
#        [[0.01, 0.  , 0.  , 0.03, 0.02, 0.08, 0.03, 0.39, 0.02, 0.43]],
#
#        [[0.06, 0.02, 0.01, 0.02, 0.04, 0.2 , 0.39, 0.03, 0.12, 0.12]],
#
#        [[0.01, 0.01, 0.11, 0.02, 0.52, 0.1 , 0.03, 0.01, 0.09, 0.11]],
#
#        [[0.01, 0.02, 0.01, 0.01, 0.07, 0.18, 0.08, 0.61, 0.02, 0.01]],
#
#        [[0.02, 0.22, 0.04, 0.26, 0.18, 0.08, 0.08, 0.04, 0.08, 0.  ]],
#
#        [[0.04, 0.06, 0.1 , 0.04, 0.29, 0.11, 0.01, 0.07, 0.26, 0.02]],
#
#        [[0.12, 0.15, 0.09, 0.04, 0.07, 0.05, 0.03, 0.37, 0.04, 0.03]],
#
#        [[0.  , 0.02, 0.16, 0.04, 0.08, 0.05, 0.04, 0.13, 0.01, 0.47]],
#
#        [[0.03, 0.13, 0.09, 0.05, 0.27, 0.12, 0.02, 0.04, 0.21, 0.02]],
#
#        [[0.12, 0.1 , 0.13, 0.07, 0.09, 0.06, 0.04, 0.06, 0.13, 0.2 ]],
#
#        [[0.15, 0.5 , 0.03, 0.02, 0.  , 0.01, 0.  , 0.09, 0.01, 0.18]],
#
#        [[0.03, 0.05, 0.1 , 0.02, 0.24, 0.01, 0.13, 0.08, 0.24, 0.1 ]],
#
#        [[0.02, 0.03, 0.01, 0.05, 0.1 , 0.27, 0.07, 0.12, 0.24, 0.08]],
#
#        [[0.15, 0.21, 0.07, 0.03, 0.03, 0.04, 0.15, 0.09, 0.24, 0.  ]],
#
#        [[0.11, 0.08, 0.01, 0.47, 0.02, 0.03, 0.24, 0.  , 0.03, 0.01]],
#
#        [[0.01, 0.1 , 0.26, 0.03, 0.21, 0.25, 0.04, 0.02, 0.04, 0.05]],
#
#        [[0.09, 0.08, 0.01, 0.2 , 0.06, 0.04, 0.04, 0.2 , 0.14, 0.14]],
#
#        [[0.  , 0.  , 0.11, 0.01, 0.21, 0.46, 0.08, 0.  , 0.01, 0.1 ]],
#
#        [[0.03, 0.03, 0.07, 0.09, 0.04, 0.34, 0.03, 0.23, 0.12, 0.02]],
#
#        [[0.01, 0.04, 0.12, 0.05, 0.34, 0.02, 0.31, 0.02, 0.03, 0.07]],
#
#        [[0.08, 0.02, 0.08, 0.07, 0.1 , 0.02, 0.08, 0.07, 0.38, 0.11]],
#
#        [[0.03, 0.09, 0.17, 0.05, 0.35, 0.1 , 0.03, 0.14, 0.01, 0.05]],
#
#        [[0.1 , 0.18, 0.06, 0.15, 0.21, 0.02, 0.1 , 0.12, 0.04, 0.01]],
#
#        [[0.03, 0.02, 0.21, 0.01, 0.22, 0.3 , 0.01, 0.16, 0.02, 0.02]],
#
#        [[0.04, 0.01, 0.06, 0.19, 0.19, 0.19, 0.04, 0.04, 0.06, 0.18]],
#
#        [[0.02, 0.2 , 0.01, 0.07, 0.16, 0.06, 0.02, 0.19, 0.14, 0.15]],
#
#        [[0.  , 0.04, 0.02, 0.04, 0.  , 0.01, 0.  , 0.79, 0.05, 0.04]],
#
#        [[0.06, 0.06, 0.03, 0.03, 0.04, 0.19, 0.02, 0.15, 0.06, 0.35]],
#
#        [[0.38, 0.03, 0.01, 0.01, 0.09, 0.09, 0.25, 0.08, 0.01, 0.06]],
#
#        [[0.06, 0.1 , 0.05, 0.04, 0.26, 0.04, 0.05, 0.15, 0.14, 0.12]],
#
#        [[0.04, 0.03, 0.02, 0.  , 0.32, 0.05, 0.02, 0.1 , 0.14, 0.28]],
#
#        [[0.02, 0.04, 0.17, 0.08, 0.13, 0.14, 0.03, 0.23, 0.11, 0.05]],
#
#        [[0.12, 0.17, 0.03, 0.02, 0.23, 0.12, 0.2 , 0.03, 0.03, 0.06]],
#
#        [[0.02, 0.02, 0.34, 0.05, 0.06, 0.13, 0.25, 0.01, 0.11, 0.02]]],
#       dtype=float32)

# %% [markdown]
# ### Max norm

# %%
layer = keras.layers.Dense(100, activation="selu", kernel_initializer="lecun_normal",
                           kernel_constraint=keras.constraints.max_norm(1.))

# %%
MaxNormDense = partial(keras.layers.Dense,
                       activation="selu", kernel_initializer="lecun_normal",
                       kernel_constraint=keras.constraints.max_norm(1.))

model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[28, 28]),
    MaxNormDense(300),
    MaxNormDense(100),
    keras.layers.Dense(10, activation="softmax")
])
model.compile(loss="sparse_categorical_crossentropy", optimizer="nadam", metrics=["accuracy"])
# Out:
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
