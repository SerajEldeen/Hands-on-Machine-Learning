# %%
import sklearn
import numpy as np
import tensorflow as tf
from tensorflow import keras
# Out:
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %% [markdown]
# ## Generate the Dataset

# %%
def generate_time_series(batch_size, n_steps):
    freq1, freq2, offsets1, offsets2 = np.random.rand(4, batch_size, 1)
    time = np.linspace(0, 1, n_steps)
    series = 0.5 * np.sin((time - offsets1) * (freq1 * 10 + 10))  #   wave 1
    series += 0.2 * np.sin((time - offsets2) * (freq2 * 20 + 20)) # + wave 2
    series += 0.1 * (np.random.rand(batch_size, n_steps) - 0.5)   # + noise
    return series[..., np.newaxis].astype(np.float32)

# %%
np.random.seed(42)

n_steps = 50
series = generate_time_series(10000, n_steps + 1)
X_train, y_train = series[:7000, :n_steps], series[:7000, -1]
X_valid, y_valid = series[7000:9000, :n_steps], series[7000:9000, -1]
X_test, y_test = series[9000:, :n_steps], series[9000:, -1]

# %% [markdown]
# ## Simple RNN

# %%
np.random.seed(42)
tf.random.set_seed(42)

model=keras.models.Sequential([
  keras.layers.SimpleRNN(1,input_shape=[None,1])
])
optimizer=keras.optimizers.Adam(learning_rate=0.005)
model.compile(loss="mse",optimizer=optimizer)
history=model.fit(X_train,y_train,epochs=20,
                  validation_data=(X_valid,y_valid))
# Out:
# Epoch 1/20
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0649 - val_loss: 0.0198
# Epoch 2/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0157 - val_loss: 0.0140
# Epoch 3/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0133 - val_loss: 0.0123
# Epoch 4/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0121 - val_loss: 0.0114
# Epoch 5/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0116 - val_loss: 0.0111
# Epoch 6/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0114 - val_loss: 0.0110
# Epoch 7/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 19s 86ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 8/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 9s 41ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 9/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 10/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 11/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 12/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 13/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 14/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 15/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 16/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 17/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 18/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 19/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 20/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0114 - val_loss: 0.0110

# %% [markdown]
# ## Deep RNN

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.SimpleRNN(20, return_sequences=True, input_shape=[None, 1]),
    keras.layers.SimpleRNN(20),
    keras.layers.Dense(10)
])

model.compile(loss="mse", optimizer="adam")
history = model.fit(X_train,y_train,epochs=20,
                  validation_data=(X_valid,y_valid))
# Out:
# Epoch 1/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - loss: 0.0385 - val_loss: 0.0088
# Epoch 2/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0063 - val_loss: 0.0047
# Epoch 3/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0044 - val_loss: 0.0038
# Epoch 4/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0039 - val_loss: 0.0035
# Epoch 5/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0037 - val_loss: 0.0033
# Epoch 6/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0035 - val_loss: 0.0032
# Epoch 7/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0034 - val_loss: 0.0032
# Epoch 8/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0034 - val_loss: 0.0031
# Epoch 9/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0033 - val_loss: 0.0031
# Epoch 10/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.0033 - val_loss: 0.0030
# Epoch 11/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0032 - val_loss: 0.0030
# Epoch 12/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.0032 - val_loss: 0.0030
# Epoch 13/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0031 - val_loss: 0.0030
# Epoch 14/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0031 - val_loss: 0.0029
# Epoch 15/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0031 - val_loss: 0.0029
# Epoch 16/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0031 - val_loss: 0.0029
# Epoch 17/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0031 - val_loss: 0.0029
# Epoch 18/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0031 - val_loss: 0.0029
# Epoch 19/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0030 - val_loss: 0.0029
# Epoch 20/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0030 - val_loss: 0.0029

# %% [markdown]
# ## Deep RNN with Batch Norm

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.SimpleRNN(20, return_sequences=True, input_shape=[None, 1]),
    keras.layers.BatchNormalization(),
    keras.layers.SimpleRNN(20), 
    keras.layers.BatchNormalization(),
    keras.layers.Dense(10)     
])

model.compile(loss="mse", optimizer="adam")
history = model.fit(X_train,y_train,epochs=20,
                  validation_data=(X_valid,y_valid))
# Out:
# Epoch 1/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 11s 29ms/step - loss: 0.1691 - val_loss: 0.0858
# Epoch 2/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.0213 - val_loss: 0.0180
# Epoch 3/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.0144 - val_loss: 0.0089
# Epoch 4/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.0120 - val_loss: 0.0068
# Epoch 5/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.0109 - val_loss: 0.0059
# Epoch 6/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.0103 - val_loss: 0.0055
# Epoch 7/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.0099 - val_loss: 0.0053
# Epoch 8/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.0096 - val_loss: 0.0051
# Epoch 9/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.0094 - val_loss: 0.0049
# Epoch 10/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.0092 - val_loss: 0.0048
# Epoch 11/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.0090 - val_loss: 0.0046
# Epoch 12/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.0089 - val_loss: 0.0045
# Epoch 13/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.0088 - val_loss: 0.0044
# Epoch 14/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.0086 - val_loss: 0.0043
# Epoch 15/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - loss: 0.0085 - val_loss: 0.0042
# Epoch 16/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.0084 - val_loss: 0.0042
# Epoch 17/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.0083 - val_loss: 0.0042
# Epoch 18/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.0083 - val_loss: 0.0042
# Epoch 19/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.0082 - val_loss: 0.0043
# Epoch 20/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.0081 - val_loss: 0.0043

# %% [markdown]
# ## LSTM

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.LSTM(20, return_sequences=True, input_shape=[None, 1]),
    keras.layers.LSTM(20),
 keras.layers.Dense(10)
])

model.compile(loss="mse", optimizer="adam")
history = model.fit(X_train, y_train, epochs=20,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - loss: 0.0574 - val_loss: 0.0285
# Epoch 2/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - loss: 0.0216 - val_loss: 0.0180
# Epoch 3/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - loss: 0.0168 - val_loss: 0.0153
# Epoch 4/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - loss: 0.0141 - val_loss: 0.0124
# Epoch 5/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - loss: 0.0102 - val_loss: 0.0081
# Epoch 6/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - loss: 0.0063 - val_loss: 0.0050
# Epoch 7/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - loss: 0.0042 - val_loss: 0.0036
# Epoch 8/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 6s 29ms/step - loss: 0.0035 - val_loss: 0.0033
# Epoch 9/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 8s 35ms/step - loss: 0.0032 - val_loss: 0.0032
# Epoch 10/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 12s 55ms/step - loss: 0.0031 - val_loss: 0.0032
# Epoch 11/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 12s 53ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 12/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 12s 55ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 13/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 12s 55ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 14/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 11s 52ms/step - loss: 0.0029 - val_loss: 0.0030
# Epoch 15/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 12s 53ms/step - loss: 0.0029 - val_loss: 0.0030
# Epoch 16/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 11s 52ms/step - loss: 0.0029 - val_loss: 0.0030
# Epoch 17/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 11s 52ms/step - loss: 0.0028 - val_loss: 0.0030
# Epoch 18/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 21s 53ms/step - loss: 0.0028 - val_loss: 0.0029
# Epoch 19/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 11s 50ms/step - loss: 0.0028 - val_loss: 0.0029
# Epoch 20/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 12s 53ms/step - loss: 0.0028 - val_loss: 0.0029

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.GRU(20, return_sequences=True,  input_shape=[None, 1]),
    keras.layers.GRU(20),
    keras.layers.Dense(10)
])

model.compile(loss="mse", optimizer="adam")
history = model.fit(X_train, y_train, epochs=20,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 37s 126ms/step - loss: 0.0464 - val_loss: 0.0079
# Epoch 2/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 15s 67ms/step - loss: 0.0050 - val_loss: 0.0042
# Epoch 3/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 8s 37ms/step - loss: 0.0044 - val_loss: 0.0040
# Epoch 4/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 8s 37ms/step - loss: 0.0043 - val_loss: 0.0039
# Epoch 5/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 8s 37ms/step - loss: 0.0042 - val_loss: 0.0038
# Epoch 6/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 10s 37ms/step - loss: 0.0041 - val_loss: 0.0038
# Epoch 7/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 8s 35ms/step - loss: 0.0040 - val_loss: 0.0037
# Epoch 8/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 8s 37ms/step - loss: 0.0039 - val_loss: 0.0037
# Epoch 9/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - loss: 0.0038 - val_loss: 0.0036
# Epoch 10/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 8s 37ms/step - loss: 0.0038 - val_loss: 0.0036
# Epoch 11/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 8s 37ms/step - loss: 0.0037 - val_loss: 0.0036
# Epoch 12/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 8s 38ms/step - loss: 0.0036 - val_loss: 0.0035
# Epoch 13/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 8s 37ms/step - loss: 0.0036 - val_loss: 0.0035
# Epoch 14/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 8s 37ms/step - loss: 0.0036 - val_loss: 0.0035
# Epoch 15/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - loss: 0.0035 - val_loss: 0.0034
# Epoch 16/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 8s 38ms/step - loss: 0.0035 - val_loss: 0.0034
# Epoch 17/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 8s 38ms/step - loss: 0.0035 - val_loss: 0.0033
# Epoch 18/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 9s 39ms/step - loss: 0.0034 - val_loss: 0.0032
# Epoch 19/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 8s 35ms/step - loss: 0.0034 - val_loss: 0.0031
# Epoch 20/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 7s 34ms/step - loss: 0.0033 - val_loss: 0.0031
